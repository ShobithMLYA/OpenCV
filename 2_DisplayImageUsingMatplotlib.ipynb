# %%
#Importing the picture
import cv2
import matplotlib.pyplot as plt

# %%
#Converting BGR to RGB and displaying it through MatPlotLib
image = cv2.imread("assets//lamp.jpg")
plt.imshow(image)
# Out:
# &lt;matplotlib.image.AxesImage at 0x1a4fda715b0&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;
